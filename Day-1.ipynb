# %%
import cv2

# %%
image = cv2.imread("kakashi.jpg")

# %%
print(image)
# Out:
# [[[247 248 246]
#   [249 250 248]
#   [251 252 250]
#   ...
#   [210 206 201]
#   [214 210 205]
#   [216 212 207]]
#
#  [[250 251 249]
#   [251 252 250]
#   [251 252 250]
#   ...
#   [226 222 217]
#   [229 225 220]
#   [229 225 220]]
#
#  [[252 253 251]
#   [252 253 251]
#   [250 251 249]
#   ...
#   [235 229 224]
#   [232 226 221]
#   [229 223 218]]
#
#  ...
#
#  [[ 81  90  64]
#   [ 76  85  59]
#   [ 76  82  59]
#   ...
#   [ 75  87  65]
#   [ 70  79  58]
#   [ 62  71  50]]
#
#  [[ 81  90  64]
#   [ 78  87  61]
#   [ 76  82  59]
#   ...
#   [ 72  84  62]
#   [ 66  75  54]
#   [ 56  65  44]]
#
#  [[ 78  87  61]
#   [ 77  86  60]
#   [ 77  83  60]
#   ...
#   [ 73  85  63]
#   [ 69  78  57]
#   [ 61  70  49]]]

# %%
print(image.shape)
# Out:
# (550, 352, 3)

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.title("Kakashi")
plt.show()
